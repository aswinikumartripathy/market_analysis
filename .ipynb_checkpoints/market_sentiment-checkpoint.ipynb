# %%
from transformers import pipeline
import numpy as np
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta
import time
from IPython.display import HTML, display, clear_output
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.dates import DateFormatter
from ipywidgets import interact, widgets
from matplotlib.ticker import FuncFormatter
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from ipywidgets import interactive

# %%
def fetch_news(url):
    # Send an HTTP request to the website
    response = requests.get(url)

    if response.status_code == 200:

    # Parse the HTML content of the page
        soup = BeautifulSoup(response.text, 'html.parser')
        # Find and extract the news elements
        news_elements = soup.find_all('li', class_='box item')

        headlines = []
        summaries = []
        date_times = []
        article_urls = []

        for news_element in news_elements:
            headline = news_element.find('h2').text
            summary = news_element.find('div').text
            datetime_element = news_element.find('span', class_='date')
            date_time = datetime_element.text if datetime_element else 'Date and time not available'
            article_url = news_element.find('a')['href']

            headlines.append(headline)
            summaries.append(summary)
            date_times.append(date_time)
            article_urls.append(article_url)

          # Create a DataFrame
            news_df = pd.DataFrame({
            'Headline': headlines,
            'Summary': summaries,
            'Datetime': date_times,
            'URL': article_urls
          })
        return news_df
    else:
            print(f"Failed to retrieve the page. Status code: {response.status_code}")
            return None

# %%
def sentiment_converter(news_dataframe):
    model = pipeline('sentiment-analysis')
    
#     news_dataframe["headline_sentiment"] = news_dataframe.Headline.apply(model)
#     news_dataframe.headline_sentiment = news_dataframe.headline_sentiment.apply(lambda x: -x[0]['score'] if x[0]['label'] == 'NEGATIVE' else x[0]['score'])
    
    news_dataframe["summary_sentiment"] = news_dataframe.Summary.apply(model)
    news_dataframe.summary_sentiment = news_dataframe.summary_sentiment.apply(lambda x: -x[0]['score'] if x[0]['label'] == 'NEGATIVE' else x[0]['score'])
    
#     news_dataframe['secs_ago'] = news_dataframe.Datetime.apply(secs_converter)
    
    return news_dataframe

# %%
def convert_to_datetime(value):
    if 'minute' in value:
        return datetime.now() - timedelta(minutes=float(value.split()[0]))
    elif 'hour' in value:
        return datetime.now() - timedelta(hours=float(value.split()[0]))
    elif 'day' in value:
        return datetime.now() - timedelta(days=float(value.split()[0]))
    else:
        return None

# %%
def static_sentiment_check(url):
    
    news_dataframe = fetch_news(url)

    news_dataframe = sentiment_converter(news_dataframe)
#     time_mean_sentiment(news_dataframe)
    news_dataframe['Datetime'] = news_dataframe['Datetime'].apply(convert_to_datetime)
    

    if news_dataframe is not None:
        return news_dataframe

# %%
def auto_refresh(url, interval_seconds, num_refreshes):
    for _ in range(num_refreshes):
        

        news_dataframe = fetch_news(url)
#         pd.set_option('display.max_colwidth', None)
        
        news_dataframe = sentiment_converter(news_dataframe)
        time_mean_sentiment(news_dataframe)
        
        if news_dataframe is not None:
#             pd.set_option('display.max_colwidth', None)
            print("Headlines ") 
            print(news_dataframe[['Headline', 'Datetime']].head(2))
            print("\n")


        time.sleep(interval_seconds)

# %%
url = "https://pulse.zerodha.com/"

# auto_refresh(url, interval_seconds=120, num_refreshes=5)

# %%
df = static_sentiment_check(url)
df = df.sort_values(by='Datetime')
# Set the 'Datetime' column as the index
df['Datetime'] = pd.to_datetime(df['Datetime'])
df.set_index('Datetime', inplace=True)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
# Assuming your dataset is stored in a DataFrame named 'df'
# Make sure you have the 'Timestamp' and 'summary_sentiment' columns

# Function to update the plot based on the selected interval
def update_plot(interval_minutes):
    clear_output(wait=True)  # Clear the previous output
    
    # Determine the time range based on the selected interval
    if interval_minutes == 1:
        time_range = pd.to_timedelta('1H')
    elif interval_minutes == 3:
        time_range = pd.to_timedelta('3H')
    elif interval_minutes == 5:
        time_range = pd.to_timedelta('6H')
    else:
        time_range = pd.to_timedelta('24H')
    
    # Resample the data to the specified interval and calculate mean sentiment
    df_resampled = df.resample(f'{interval_minutes}T').mean().last(time_range)

    # Extract time from the timestamp
    df_resampled['Time'] = df_resampled.index.time

    # Format the x-axis labels to show both date and time at midnight,
    # and show only time for other intervals
    df_resampled['x_labels'] = [
        f'{date.strftime("%Y-%m-%d %H:%M")}' if (time >= pd.Timestamp('00:00:00').time() and time <= pd.Timestamp('00:30:00').time()) else f'{time.strftime("%H:%M")}'
        for date, time in zip(df_resampled.index, df_resampled['Time'])
    ]

    # Set color based on sentiment directly without a color scale
    df_resampled['colors'] = ['green' if sentiment >= 0 else 'red' for sentiment in df_resampled['summary_sentiment']]

    # Create a Plotly figure with a consistent size
    fig = go.Figure()

    # Add stacked bar traces
    fig.add_trace(go.Bar(
        x=df_resampled.index,
        y=df_resampled['summary_sentiment'],
        marker_color=df_resampled['colors'],
        hovertemplate='Datetime: %{x|%Y-%m-%d %H:%M}<br>Mean Sentiment: %{y:.4f}',
    ))

    # Set x-axis labels and tilt them to the left
    fig.update_layout(
        title=f'Stacked Plot with Mean Sentiment for Each {interval_minutes}-Minute Interval',
        xaxis_title='Datetime',
    )

    # Calculate tickvals and ticktext
    if interval_minutes != 0:
        tickvals = np.linspace(0, len(df_resampled) - 1, num=len(df_resampled) // max(1, int(30 / interval_minutes)), endpoint=True, dtype=int)
        ticktext = [pd.Timestamp(x).ceil('30T').strftime('%Y-%m-%d %H:%M') for x in df_resampled.index[tickvals]]
    else:
        tickvals = np.arange(0, len(df_resampled), dtype=int)
        ticktext = [df_resampled['x_labels'].iloc[i] for i in tickvals]

    # Set x-axis ticks
    fig.update_layout(
        xaxis=dict(
            tickmode='array',
            tickvals=df_resampled.index[::int(60 / interval_minutes)],
            ticktext=df_resampled['x_labels'][::int(60 / interval_minutes)],
        
#         tickvals=df_resampled.index[tickvals].tolist(),
#         ticktext=ticktext,
            tickangle=-45,  # Tilt the labels to the left
        ),
    )

    # Remove the color legend and color scale
    fig.update_layout(
        showlegend=False,
    )

    # Consistent figure size
    fig.update_layout(
        autosize=False,
        width=1000,
        height=600,
    )

    # Show the plot
    fig.show()

# Create a dropdown widget for selecting the interval
interval_dropdown = widgets.Dropdown(
    options=[1, 3, 5, 15, 30, 60],  # Options in minutes
    value=5,  # Initial value
    description='Interval (in min):',
    style={'description_width': 'initial'},  # To allow space for longer description
    format='0',  # To remove trailing '.0' in the displayed values
)

# Create an interactive widget
interactive_plot = interactive(update_plot, interval_minutes=interval_dropdown)

# Display the widget and initial plot
display(interactive_plot)
# Out:
# interactive(children=(Dropdown(description='Interval (in min):', index=2, options=(1, 3, 5, 15, 30, 60), style…

# %%
df.tail()
# Out:
#                                                                      Headline  \
# Datetime
# 2024-01-18 20:56:11.721549  FinAGG Technologies raises $11 million in Seri...
# 2024-01-18 20:57:11.721549  Orry's viral clip from Koffee with Karan has t...
# 2024-01-18 20:58:11.721549  Puravankara posts 89% growth in pre-sales in 9...
# 2024-01-18 21:05:11.721549  Passengers grab phone snatcher through train w...
# 2024-01-18 21:12:11.721549  Epack Durable IPO | Institutional investors pi...
#
#                                                                       Summary  \
# Datetime
# 2024-01-18 20:56:11.721549  The fintech, which provides working capital lo...
# 2024-01-18 20:57:11.721549  'I take great pride in being everywhere -- Orr...
# 2024-01-18 20:58:11.721549
# 2024-01-18 21:05:11.721549  The undated video, reportedly from Bihar’s Bha...
# 2024-01-18 21:12:11.721549  Epack Durable IPO | Optimix Wholesale Global E...
#
#                                                                           URL  \
# Datetime
# 2024-01-18 20:56:11.721549  https://www.moneycontrol.com/news/technology/f...
# 2024-01-18 20:57:11.721549  https://www.moneycontrol.com/news/trends/orry-...
# 2024-01-18 20:58:11.721549  https://www.thehindu.com/business/puravankara-...
# 2024-01-18 21:05:11.721549  https://www.moneycontrol.com/news/trends/passe...
# 2024-01-18 21:12:11.721549  https://www.moneycontrol.com/news/business/ipo...
#
#                             summary_sentiment
# Datetime
# 2024-01-18 20:56:11.721549          -0.965190
# 2024-01-18 20:57:11.721549          -0.529088
# 2024-01-18 20:58:11.721549           0.748121
# 2024-01-18 21:05:11.721549          -0.997367
# 2024-01-18 21:12:11.721549           0.797690

# %%
import requests
from bs4 import BeautifulSoup

# Replace the URL with the actual website URL
url = "https://pulse.zerodha.com/"

# Define your search query
search_query = 'HDFC Bank'

# Perform a GET request to the website
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the search bar element by its HTML attribute (e.g., name, id, class)
    search_bar = soup.find('input', {'name': 'search'})  # Replace with the actual attribute

    # Extract any additional form parameters if needed
    form_data = {
        'search': search_query,
        # Add any other form parameters as needed
    }

    # Perform a POST request with the search query
    search_results = requests.post(url, data=form_data)

    # Parse the search results using BeautifulSoup
    search_soup = BeautifulSoup(search_results.text, 'html.parser')

    # Extract and print relevant information from the search results
#     headlines = search_soup.find_all('h2', {'class': 'headline-class'})
    news_elements = soup.find_all('li', class_='box item')
    for news_element in news_elements:
        headline = news_element.find('h2').text
        headlines.append(headline)
    print(len(headlines))
    if len(headlines) >0:
            for headline in headlines:
                print(headline)
        
        
#         for index, headline in enumerate(headlines, start=1):
#             print(f"{index}. {headline.text}")
    else:
        print("No headlines found.")

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# 1576
# India takes investment spotlight while risks weigh in China: Suntory CEO Takeshi Niinami
# ayodhya-ram-mandir-ram-janmabhumi-inauguration-live-updates
# China's Mutual Funds Implode At Fastest Pace In Five Years As Stocks Sink
# India: Marketer’s dream or Piketty’s nightmare?
# Ramkrishna Forgings is riding the CV upswing, but stock at an elevated level
# China Swap Market Goes Into Overdrive As Traders Seek FX Bypass
# Nifty bull run to last till April, but be very cautious from mid-May to July: Astro cycle expert
# Konstelec Engineers SME IPO: Check price band, GMP, financials, risks and listing date
# Morning or evening: Which is the better time to go on a walk for best fitness results?
# Dixon Tech may trade lower after inspection by DRI
# Agri Picks Report January 19, 2024: Geojit
# Bloodbath among risk-on assets – Disappointing HDFC earnings, or something more systemic?
# Dollar Dominance Is Triggering Intervention Fears Across Markets
# Q3 results today: RIL, HUL, Paytm, UltraTech among 46 companies to announce earnings
# Stock Market Live: Nifty, Sensex Higher In Pre-Open; RIL, SBI, Lupin, HUL In Focus
# RIL Q3 results today: What to expect from the conglomerate; how to trade the stock?
# Japan's space programs and moon missions
# Rising Interest Rates Threaten India’s Credit Growth And Pressure Margins
# Budget Snapshot: Do tax resets make Indians change investments?
# Gold set for weekly drop on tempered rate-cut view
# Japan counts down to precision 'moon sniper' landing mission
# Oil prices drift lower on China demand worries
# D-Street poised to snap 3-day losing run, IndusInd Bank, Polycab’s Q3 show and more | Market Minutes
# Ram Mandir inauguration updates Live: Odisha, Rajasthan govt declare half-day holidays on Jan 22
# Dollar headed for second weekly gain on tempered rates outlook
# Asian shares bounce on global tech rally, yen loser of the week
# Pakistani woman faces backlash for post praising groom who took Alto instead of luxury car to wedding
# Cash Market | PNB shows a robust underlying bullish trend
# US strikes Houthi anti-ship missiles, shipping disruptions grow
# This Segment Within Defence Stocks Is A Preferred Bet For Complete Circle's Gurmeet Chadha
# TSMC Outlook Drives $165 Billion Chip Rally In 2024 Rebound Bet
# Bank CEOs, huddled in Davos, said to worry on competition, economy
# Bangladesh solar power surge set to unlock thousands of green jobs
# Sensex Today | Stock Market LIVE Updates: GIFT Nifty signals a positive start; Asian shares trade higher
# YouTube And Spotify Won’t Launch Apple Vision Pro Apps, Joining Netflix
# Red Sea Unrest Is Bad News For The World’s Fragile Food Supply
# Bitcoin Retreats To One-Month Low As ETF-Led Enthusiasm Wanes
# Huthis say US ship hit in Gulf of Aden attack
# Global Passive Funds Put Added Strain On China’s Stock Rout
# Japan inflation slows in December as energy bills drop
# MC Policy Next | India may aim for a fiscal deficit of 5.3% for FY25: India Ratings' Pant
# budget-2024 expectations live union budget fm sitharaman modi budget interim budget
# Stock Radar I Eye on FMCG space! United Breweries is in a steady long-term uptrend: Ajit Mishra
# Is the RBI targeting banking executives?
# Agri talks a no-go for India at WTO meet without public stockholding solution
# Stock Market Today: Top 10 things to know before the market opens
# Bosch aims to cut 1,200 jobs in software division by end 2026
# Asian Equities Rise As Tech Rally Bolsters Mood: Markets Wrap
# Google to invest $1 billion in UK data centre
# Meta ramps up AI efforts by building chip arsenal, consolidating teams
# MC Exclusive | India at the forefront of energy transition: power minister RK Singh
# ESMA likely to seek board help to resolve stalemate with RBI
# SBI taps ARCs for sale of Hindusthan National Glass loan
# FPI ownership of Indian g-secs surges to a record
# Central Bank, 10 others file bids for Future Enterprises assets
# IndusInd's Q3 Net Up 17% on Strong Retail Loan Demand
# Sony calls board meeting today for Zee merger call
# Hot Stocks: Amber Enterprises, Lupin, Rail Vikas Nigam may fetch double-digit returns
# Pre-market action: Here's the trade setup for today's session
# Stocks in news: RIL, Paytm, HUL, IndusInd Bank, HDFC Bank
# Ahead of IPO, EPACK Durable mobilises Rs 192 crore from anchor investors
# Rashi Peripherals IPO | Madhu Kela's wife, Volrado Venture invest Rs 150 cr before RHP
# IndusInd Bank to open 4 more branches in Ayodhya
# Oracle Financial Services soars 27%, analysts still optimistic
# Moneycontrol Daily: Your Essential 7
# SBI raises Rs 5,000 crore through AT-1 bonds
# FPI selloff in HDFC could boost weight in MSCI index
# FPIs breaching exposure levels to reveal ODI holder details
# Reliance Industries, HUL, UltraTech Cement Q3 Results Today — Earnings Estimates
# Stock Market Today: All You Need To Know Going Into Trade On Jan. 19
# Stocks To Watch: IndusInd Bank, SBI, REC, JSW Infrastructure, Lupin, Bandhan Bank, Wipro
# 71% Of Indian Retailers Plan To Adopt Generative AI In Next 12 Months: EY Survey
# Vulnerability to climate change making food inflation structural: RBI economists
# Illegal constructions demolished from govt land worth Rs 87 crore in Greater Noida
# Israel-Hamas war tensions inflame the Middle East as fighting persists in Gaza
# Netanyahu says he has told US that he opposes Palestinian state in any postwar scenario
# BSF carries out search op after reports of suspicious tunnel in J-K's Samba
# Lufthansa pulling flight capacity from other countries to meet booming India demand
# Death of bus passengers by electrocution: After NHRC recommendations, Rajasthan to pay Rs 30L relief
# EAM Jaishankar, Maldivian Foreign Minister Zameer hold talks in Kampala
# BlackRock’s Bitcoin ETF Is First To Cross $1 Billion Threshold In Inflows
# IndiGo Evaluating Options To File Appeal Against BCAS Order
# Davos Diaries 2024: India's Emergence And The Quest For Global Trust
# Mahindra expects to sustain growth momentum in SCV segment next fiscal
# Tata Steel to shut down blast furnaces in UK, 3,000 jobs at risk: Reports
# Jawa Yezdi Motorcycles eyes ASEAN market for Jawa exports
# 'Khichdi scam' case: Shiv Sena (UBT) functionary sent to ED custody till Jan  22
# MEHAIR Places Conditional Order For Up To 20 ZA600 Hydrogen-Electric Engines With ZeroAvia
# India Central Bank Not Discussing Rate Cuts Yet, Shaktikanta Das Says
# Alaska Air Passengers Sue Airline Over 737 Max 9 Door Blowout
# Don't park planes in remote bays when there are long flight delays: MoCA tells airlines
# Sense Of Urgency Required To Tackle Intertwined Crises Of Climate, Poverty, Fragility: World Bank Chief
# Exclusive-Reddit seeks to launch IPO in March: Sources
# TRP Rigging: No Objection To Police Plea To Withdraw Case, Complainant Tells Court
# India, France to jointly fund science research projects
# FinAGG Technologies Secures $11 mn Funding Led By Blue Orchard, Tata Capital
# India must sustain growth momentum, secure at least 7% growth in FY25 - RBI bulletin
# Trade setup for Friday: 15 things to know before opening bell
# Passenger assaulting pilot unacceptable' says IndiGo CEO Pieter Elbers
# EPACK Durable Mobilises Rs 192 Crore From Anchor Investors Ahead Of IPO
# Jindal Stainless Reports 35% Rise In Q3 Net Profit; Sales Grow 9% To 5.12 LT
# Davos 2024: India Offers Opportunity For Manufacturing, Says Tamil Nadu Minister TRB Rajaa
# Global Leaders Meet DPIIT Secretary, Express Commitment To India Growth Story
# Boosting Iron Ore Production To Meet Domestic Demand; No Plans For China Exports: NMDC
# US bonds keep bearish tone after strong jobs data
# Four persons crushed to death by express train in Jharkhand
# 'Historic moment': Hindu outfits in UK welcome Ram temple consecration ceremony
# Antunes opens new unit in city to serve quick service restaurants
# Integrow to invest ₹100 crore in Paranjpe Scheme’s realty project
# Airstrikes On Yemen Bring New Level Of Chaos To Shipping In The Southern Red Sea
# Torrent Power Raises Rs 750 Crore Via Non-Convertible Debentures
# U.S. Jobless Claims Plunge To 187,000, Lowest Since September 2022
# Davos 2024: Clients charged up about Gen AI, says Infosys CEO Salil Parekh
# ‘Mobile services will cost more after polls’
# Ahead of Market: 10 things that will decide D-Street action on Friday
# SBI raises ₹5,000 crore through bond issue
# Gift Nifty, HDFC ADR shares show signs of positivity, trade higher
# India Plans To Push WTO To Ease Subsidy Rules On Grain Purchase
# Time ripe for aircraft assembly line in India: Scindia
# Davos 2024: PM Modi’s successful foreign policy will make India major semiconductor destination in 5 years, says Ashwini Vaishnaw
# Davos 2024: India To Be Key Player In Green Ecosystem, Says INOX Group's Siddharth Jain
# Sexual pleasure is 'a gift from God', lust 'devastates relationships' says Pope Francis
# Birkenstock falls 14% as investors focus on profit warning in first post-IPO results
# Ayodhya Ram Mandir: Bus travel spikes ahead of inauguration, more services in offing
# Davos 2024: HCLTech CEO Vijayakumar Expects Discretionary Spending To Pick Up
# Ahead of IPO, Epack Durables raises Rs 192 crore from marquee investors in anchor round
# Epack Durable IPO | Institutional investors pick Rs 192 crore shares via anchor book
# Coal India likely to mine critical minerals
# Passengers grab phone snatcher through train window, drag him for 1 km. Video
# Puravankara posts 89% growth in pre-sales in 9 months
# Orry's viral clip from Koffee with Karan has the internet 'uncomfortable and intrigued'. Watch
# FinAGG Technologies raises $11 million in Series A funding round
# Mahua Moitra says she's hospitalised, urges HC for direction to authorities to not evict her from govt bungalow
# Illicit crypto addresses received at least $24.2 billion in 2023: Report
# South Indian Bank Q3 Results: Net profit soars 197% YoY to Rs 305.36 crore
# NSE Remains World's Largest Derivatives Exchange For Fifth Straight Year
# Economy to log stronger-than expected growth in FY24: RBI officials
# Spot bitcoin ETFs draw nearly $2 billion in first three days of trading
# Ashok Leyland bags orders for 1,225 Viking buses from Karnataka STUs
# MC Exclusive: Govt mulls compulsory fake review prevention system for e-commerce platforms
# US bank regulator: New liquidity rules needed to handle bank runs
# Jeh Aerospace Raises $2.75 Million From General Catalyst, Others
# DefSat Conference To Bring Space Strategists Together From Feb 7-9
# Bulk deals: Citibank sells further stake in Grasim, foreign investor sells IEX shares
# Davos 2024: Shaktikanta Das Expects 7% Real GDP Growth In FY25, Inflation To Moderate
# REC Designated As Implementation Agency For Rooftop Solar Programme
# Birkenstock Q4 Results: Company beats revenue expectations on strong demand
# Consumer affairs get daily data from 550 centres on 22 food commodities: Rohit Kumar Singh
# Iran-Pakistan conflict: Regional equilibrium teeters, global powers on edge
# NSE world's largest derivatives exchange for fifth year in a row; third in equity
# S&P 500, Nasdaq open higher on chips, megacaps boost
# After Pakistan's counter-strikes on Iran, China offers to play a constructive role  to ease tensions
# Paytm Q3 preview: Strong revenue growth, narrower net loss seen on better operating performance
# DBS Bank Collaborates With StartupTN To Provide Support To Over 1,000 Early-Stage Enterprises
# Startup Groyyo Secures Rs 40 Crore Funding From Lighthouse Canton, Trifecta Capital
# FSSAI Directs Airline Caterers To Comply With Food Safety Rules
# Govt launches fresh incentive scheme for green hydrogen, green ammonia production based on demand aggregation
# Tata Communications posts fastest quarterly revenue growth in 9 years
# US applications for jobless benefits fall to lowest level since September 2022
# Alpha Wave-backed Groyyo secures $5.4 million in venture debt
# RBI calls upon internal ombudsmen to give inputs for enhancing processes
# On camera, TTE slaps passenger repeatedly on Barauni-Lucknow Express. Railway Minister reacts
# Matter of concern: India on situation in Red Sea
# Indian economy poised to sustain growth momentum: RBI report
# Metro Brands Q3 net profit declines 12.6 pc to Rs 98.78 cr
# Higher US yields, hawkish cenbank comments push India bond yields up
# India Estimated To Have Harvested 355.35 mn Tonnes Horticulture Crops In 2022-23: Agri Ministry Data
# Govt May Look For Providing Incentives Or Supporting Initiatives To Retrofit Old Vehicles Into EVs: Report
# Gold climbs as weaker dollar, safe-haven demand lend support
# FPIs Stay Net Sellers For The Second Straight Day
# ET Market Watch: Sensex and Nifty close lower, HDFC Bank & LTIMindtree slip
# Market Trading Guide: Bank of Maharashtra, Castrol India among 5 stock recommendations for Friday
# Puravankara Shares Surge After Company Unveils 2nd Plotted Development Project Near Chennai
# Sebi issues demand notices to DHFL's former promoters in disclosure rule violation case
# Top Seven Business And Stock Market News Of The Day You Can't Miss — Jan. 18
# RBI Governors says topic of rate cut not on table at this time, focus to bring inflation to 4%
# Metro Brands Q3 net profit declines 12.6% to Rs 98.78 crore
# Six school students on picnic die as boat overturns in lake near Vadodara; several others missing
# IESA demands 10-year tax holiday on standalone battery energy storage using renewables
# Gem, Jewellery Exports Slip 8.14% To Rs 18,281 Crore In December: GJEPC
# PhonePe Sells 90 Lakh Digital Insurance Policies, 40 Lakh In Just One Year
# Market Rally Has Margin Trading Book Hitting A Record Rs 54,537 Crore In Jan
# Davos 2024: Japanese Monetary Authority to adopt India's digital payment models says Ashwini Vaishnaw
# Davos 2024: Apollo Tyres Expanded Return On Capital Employed Using AI, Says Vice Chairman
# HDFC Bank share crash and the perils of equity funds that hug their benchmarks
# Brave Souls Foundation's Fight for Acid Attack Survivors | Badlaav Humse Hai Season 2
# Aadhaar will not be considered as valid proof of date of birth: EPFO
# IndiGo vows to return to earlier on-time performance standards
# OpenAI Coup Less Stressful Than Superintelligent AI, Sam Altman Says
# Oil Squeeze Of 2023 Turns To Surplus In Warning For Market Bulls
# 8 financial services stocks hit 52-week highs; rallied up to 55% in a month
# Mysuru-Based Rangsons Aerospace Inks 5-Year Contract With Boeing
# KRN Heat Exchanger Files Draft Papers To Raise Funds Via IPO
# Lupin Gets USFDA Nod to Market Generic Hyperuricemia Treatment Drug
# ICRA Projects GDP Growth To Moderate To Below 6% In Q3
# Maersk Opens New Cold-Chain Facility In Gujarat
# IHCL Opens Hotel In Jaisalmer
# Reddit seeks to launch IPO in March
# RBI hasn't mandated number on CD ratio: Governor
# Rupee rises 2 paise to 83.12 against U.S. dollar
# Energy Efficiency Services inks 5 initial pacts to boost energy efficiency, renewables
# Davos 2024: RMZ Corp's Manoj Menda Sees India As Most Promising Real Estate Market In 2024
# Moneycontrol Policy Next LIVE | Navigating India's $10 trillion economy
# True Detective Night Country review: Jodie Foster & Co deliver one of the franchise’s best seasons
# Government to sell additional 1% stake in NHPC as OFS gets overwhelming response
# Ram Mandir Ayodhya: Here’s everything about the ‘Time Capsule’ readied to be placed 2,000 feet under temple
# India needs 2,840 new aircraft, 41,000 pilots in next 20 years: Airbus forecast
# RBI imposes monetary penalty on three cooperative banks
# Bengaluru blushes as pink blossoms shroud city in glory. How they came to India
# Wings India 2024: Asia's premier aviation event marks India's industry growth, global recognition
# Woman arrested for staying at Delhi 5-star hotel for 15 days without paying
# Ashok Leyland Secures Supply Order For 1,225 Buses For Karnataka State Transport Undertakings
# NHPC OFS: Institutional Buyers Put In Bids Worth Rs 6,000 Crore
# Technical Breakout Stocks: How to trade OFSS, PCBL and Sobha on Friday
# House Of Abhinandan Lodha To Invest Rs 1,200 Crore In Ayodhya
# Commerce Ministry To Launch Portal To Provide Info For Aspiring Exporters
# Airbus Forms JV With Air India To Launch Pilot Training Centre in Gurugram
# Stock market update: Fertilisers stocks  down  as market  falls
# JK Tyre, Saregama among 6 smallcap stock picks by Emkay
# Jet Airways Case: Top Court Asks Jalan-Kalrock Consortium To Deposit Rs 150 Crore By Month-End
# Pakistan’s Army Strikes Back At Iran As Both Sides Urge Calm
# Nifty Bank falls for 3rd day, closes below 46,000; next support seen at 45,500
# Pakistan conducts 'precision military strikes' against 'terrorist hideouts' in Iran's Siestan-Balochistan province, 9 killed
# Gainers & Losers: LTIMindtree, Oracle Financial among top 5 stocks in spotlight
# More banks rush to Ayodhya eyeing business opportunities
# GMR Group, IndiGo Airlines Tie Up For Digital Transformation In Indian Aviation
# Meta Says Its AI Tools Boost Ad Campaigns’ Returns By 32%
# Oil Markets Look ‘Reasonably Well Supplied’ In 2024, IEA Says
# IEX, ICICI Lombard General Insurance among 5 stocks with top-long unwinding
# A decade in turmoil: Here is the timeline of tensions in Iran-Pakistan conflict
# Tea Board Mandates Generation Of Tea Waste Not Exceeding 0.2% Of Production
# Ayodhya Ram Mandir | Whose land is it anyway — events and legal cases from 1608 to 1992
# Markets Will See A Comeback If Nifty Sustains Above 21,450, Say Analysts
# Puravankara to develop 3 million sq ft of residential space in Chennai, announces launch of largest plotted development
# Interest Rates To Keep Falling But Last Mile 'Very Very Tricky': IMF Chief
# Share market update: Most active stocks in today's market in terms of volume
# Welspun Corp's Associate Arm EPIC Bags Rs 3,000 Crore Orders In Saudi Arabia
# Akasa Air, IndiGo, Air India Place Orders For 1,120 Planes In Less Than One Year
# Aether Industries Partners With Novoloop For Sustainable Plastic Management
# India among most vibrant fintech hubs: WEF study
# France ramps up weapons production for Ukraine and says Russia is scrutinizing the West's mettle
# Davos 2024: India to be fastest growing G20 economy, will drive global growth, says OECD chief
# Weak earnings, fading US rate cut hopes drag Indian shares
# Sterling and Wilson Renewable Energy loss narrows in Dec quarter
# Oil prices rise on strong IEA and OPEC demand estimates
# Stock market update: Stocks that hit 52-week highs on NSE in today's trade
# LTIMindtree portfolio of revenues rebalancing, holds better promise for multi-year growth path: Sudhir Chaturvedi
# SBI Raises Rs 5,000 Crore Through AT-1 Bonds At Coupon Of 8.34%
# RIL Q3 results preview: Here's what to expect
# Polycab Q3 Results: Profit Rises In Line With Estimates
# Airbus says to double procurement from India to $1.5 billion
# With GPT Store, OpenAI is going after the attention economy
# These 5 smallcap MFs gave over 55% returns in a year
# Gainers and Losers: 10 stocks that moved the most on January 18
# KRN Heat Exchanger and Refrigeration files papers for IPO
# Haldiram's seeks to buy Indian chips maker Prataap Snacks
# Epack Durables IPO opens tomorrow. What GMP signals ahead of subscription
# Live: How can technology amplify humanity? Sam Altman at WEF | Davos 2024
# Sensex falls for 3rd day, ends 314 pts lower; Nifty below 21,500
# 2 stocks to buy in a melting market: CA Rudramurthy BV
# MC Interview | Infra co boards reluctant to invest, revamp of PPP model may help assuage concerns: Vinayak Chatterjee
# Rupee ends flat, wedged between Asia FX bump and foreign banks' dollar buys
# Market Live: Nifty ends below 21,500, Sensex slips 314 pts; Pharma shines, Banks slip| Bajar Gupshup
# Sensex falls for third day, ends 314 points lower dragged by financials
# Going forward, Asian Paints may need to revise margin guidance in Q4 and Q1:  Amit Syngle
# Ajmera Realty, Keystone Realtors Partner To Redevelop Housing Project Worth Rs 760 crore
# Experts Hail India's Digital Public Infra For Reducing Inequality
# Accenture, SandboxAQ Tie Up Over AI-Driven Threat, Quantum-Based Decryption Attack Protection
# Dynamatic Technologies Shares Hit Fresh Record On Inking Contract With Dassault Aviation
# Apollo Tyres, RVNL among 5 midcaps that hit fresh 52-week highs on Thursday
# Ram Lalla Pran Pratishtha: Centre declares half-day holiday for central government offices on January 22
# Budget 2024: Elevated public debt levels are here to stay
# Polycab India Q3 Results: Consolidated PAT rises 15% YoY to Rs 413 crore; revenue up 17%
# Bounce partners with SUN Mobility to deploy 30,000 EV scooters by February
# Will take darshan of Lord Ram in Ayodhya after construction of temple is over: Digvijaya Singh
# Nearly 100 Deals Involving 2,707 Acres Closed In 2023: Anarock
# Flight delayed or cancelled without notice? here’s what you can do
# Moneycontrol Pro Panorama | Are the odds against equities rising?
# Transparent system, people's participation led to poverty decline: PM Modi
# Mahindra Holidays & Resorts India to invest Rs 800 crore to set up 3 new resorts in Tamil Nadu
# Ayodhya Ram Mandir FAQs: From cost of temple to guest list, all you need to know
# Sandeep Tandon on taking the right call to sell banks and how to navigate the difficult phase of bull market
# D-Street Wishlist: 8 likely changes in Interim Budget that investors must watch out for
# F&O stocks: HDFC Bank, Asian Paints among 5 stocks with short buildup
# MS Dhoni Defamation Case: What Is It About?
# Coal India Units Get Cabinet Nod For Equity Investment In Thermal Power Plants
# Medical devices firm SIGH plans to set up manufacturing facility in Hyderabad with ₹231.5 crore
# Share price of ICICI Pru Life  falls  as Sensex  drops  390.02 points
# Buy ICICI Lombard General Insurance Company; target of Rs 1740: Sharekhan
# Bitcoin ETF approval: How has the crypto market outlook changed
# Hudco on the verge of breakout, technical analyst recommends 'buy' in Rs 136-138 zone
# RK Vishnoi on NHPC’s roadshow, OFS plans and future plans
# Union Budget 2024: Ensure low cost capital to buyers and sellers and lower taxation on real estate
# Tata Elxsi  declines  3.51% as Sensex  slides
# Indian Banking System Is Robust: RBI Governor Shaktikanta Das To Moneycontrol | #Exclusive | Davos
# Davos 2024: Atal Setu Sea Link will increase connectivity in Mumbai, says HCC's Ajit Gulabchand
# Hockey Olympics qualifier semifinal: India Women look for deliverance as they take on Germany
# 71% of wealthy Indians seek luxury real estate, Goa top hotspot for vacation homes: ISIR Survey
# Dolly Khanna trims stake in multibagger Chennai Petroleum, cuts in 2 smallcaps
# Airbus signs pact with Tata Advanced Systems, Mahindra Aerospace Structures for aircraft components
# Share price of Mphasis  falls  as Nifty  weakens
# IPO rush isn't a bubble, but out of 10 issuances, we may pick 1 or 2: Bandhan AMC’s Manish Gunwani
# Qualitek Labs IPO: Check subscription on Day 1, GMP and other details
# BofA Sees India Credit Growth Speeding Up After Polls On Capex
# Ashish Kacholia trims stake in multibagger Balu Forge, hikes in this smallcap
# Indian Railways To Learn Swiss Railway's Best Practices, Says Vaishnaw
# Air Passenger Traffic In India Likely To Reach 300 Million By 2030: Jyotiraditya Scindia
# Zee shares rally 7% on report Punit Goenka offers to step down to seal Sony merger deal
# LTIMindtree Won’t Be As Profitable As Expected In Fiscal 2024, CEO Says
# Where to invest within the pharma theme? Industry expert Kewal Handa answers
# Crypto Price Today: Bitcoin trades near $42,800; Polygon, Toncoin shed up to 4.5%
# Arvind Kejriwal to visit Goa for three-day visit amid ED summons
# Unicorns selfie: 'Startups club' discussion with Piyush Goyal continued till 11pm, says Paytm CEO
# Cabinet approves creation of three posts for 16th Finance Commission
# HUL Q3 results preview: Subdued show to continue on muted demand, weak pricing environment
# Priyanka Chopra, Nick Jonas celebrate daughter Malti's 2nd birthday with special puja. Madhu Chopra joins
# Samsung to bring Galaxy AI features to S23 series, Tab S9 and Z foldables
# RIL Q3 result preview: PAT, revenue likely to see modest growth YoY on weak O2C show
# Boeing Wins Order For 150 Max Jets From Akasa Air
# HDFC Bank: Unbridled Expectations Or Communication Gap?
# Osiajee Consolidated December 2023 Net Sales at Rs 0.43 crore, down 38.85% Y-o-Y
# Sun Pharma's Move To Fully Acquire Taro Is A Good Proposition, Say Analysts
# Want to create wealth? 5 themes which investors should track in 2024: Varun Saboo
# Akasa Air places order for 150 Boeing 737 Max planes
# Covid-19: India Logs 305 New Cases
# Coforge, Mphasis among 5 stocks with short buildup
# Maharashtra Inked MoUs Worth Rs 3.53 Lakh Crore At WEF In Davos: CM Shinde
# Sensex, Nifty Trade Lower As HDFC Bank, LTIMindtree, Asian Paints Drag: Midday Market Update
# Are the bulls getting tired now?  How long will the rally across PSUs continue? Harsha Upadhayaya explains
# Delhi Weather News LIVE Updates: Fog disrupts visibility and rail traffic in North, northeast India
# Persistent Systems’ board to consider stock split; share volatile
# ICICI Pru Life shares tank 10% post muted Q3 earnings show
# GM Mustard: SC reserves order on pleas seeking moratorium on release of GMOs into environment
# Aarti Industries rallies 8% on Rs 6,000-cr chemical deal with multinational
# Vinati Organics Q3 PAT may dip 29.8% YoY to Rs. 88 cr: Prabhudas Lilladher
# 2024 - Year of opportunities!
# International Battery Company raises $35 million led by RTP Global
# Oracle Financial Services Software zooms 20% to record high on robust Q3 numbers
# Exploring the Benefits of a Small Personal Loan from Poonawalla Fincorp
# Beyond 3:30 pm! Why extending stock market timings should be explored
# HCL Tech To Collaborate With Cisco For Cloud-Native Solutions
# Taro announces merger with Sun Pharma in ₹2,892 crore deal
# Budget may disappoint stocks related to government capex: Jefferies
# Despite selling by Dalal Street big bulls, 4 smallcap stocks turned multibaggers in Q3
# Slight cannibalisation always happens but Tatas launching EVs in distinctly different segments: Shailesh Chandra
# Shares of Shree Cements  fall  as Nifty  drops
# Technical Stock Pick: ONGC hits 52-week high in January 2024, rallies over 20% in 3 months – should you buy, sell or hold?
# Spiritual Tourism is the new buzzword on D-St! Don’t ignore these 6 stocks for your long term portfolio
# ICICI Pru Life sees biggest crash in one year, stock down 10% after Q3 misses estimates
# Gold Rate Today: Yellow metal’s 2024 losses rise to Rs 1,650/10 grams. What should traders do?
# BHEL looks at opportunities in India’s rising energy demand
# Maxposure IPO allotment soon: Check status, GMP, listing date and other details
# ‘Amazon fired me’: Employee loses job of 7 years over TikTok video
# Airbus, Air India to jointly set up training centre in India; aim to train 5000 pilots in the next decade
# Weak Communication By Management May Have Caused HDFC Bank's Market Fall—Exclusive
# Premonition? Mutual funds sold 2.5 crore shares of HDFC Bank last month
# Over 32% companies globally declared layoffs in 2023, IT services lead the league: Report
# LTI Mindtree Q3 FY24 – quarter marred by seasonality
# Asian Paints shares fall 6% post Q3 earnings. Should you buy, sell or hold?
# Davos 2024: 65% of employees working from office 3-5 days a week, says TCS CEO K Krithivasan
# Bengaluru techie’s mid-air horror of being trapped in SpiceJet loo:  ‘Was thrown around during landing’
# Tata Unit Agratas In India Is In Talks For Green Loan Of Up To $500 Million
# Asian Paints Q3: Brokerages positive on rural recovery, competition a worry. Buy, sell or hold?
# Could money move out of HDFC Bank to Bajaj Finance or is it time for sector rotation? Hemang Jani asnwers
# HDFC Bank shares tank 12% in 2 days in Rs 1.3 lakh-crore rout. No dip buyers left
# Buy Tarsons Products, target price Rs 670:  ICICI Securities
# HDFC Bank Extends Losses, Wipes Off Over Rs 43,000 Crore In Market Value
# The Majority Of Asia’s Professionals Want A New Job This Year
# Australian Premium Solar debuts with 159% premium over IPO price on NSE SME
# Intergenerational Investing: The challenge of protecting and preserving wealth across generations
# Sensex  falls! These  stocks are down 5% or more on BSE
# Samsung Galaxy Unpacked 2024: Galaxy S24 series launched, Samsung bets big on Galaxy AI
# Karnataka to recover Rs 75 cr from 8 firms for failure in imparting skill education despite aid
# How can Indians invest in Bitcoin ETFs in the US? BitBNS' Gaurav Dahake answers
# Paytm Q3 result preview: Losses to narrow on improved operating performance; solid revenue growth eyed
# Budget Snapshot: Will government risk increasing capex spends in interim budget?
# New Swan Multitech sees 90% premium listing over IPO price
# LIVE: Indian equities to see more cuts | HDFC bank ADR slumps, NHPC OFS opens | Opening Bell
# Australian Premium Solar shares debut with 159% premium over issue price
# Balaji Amines trades lower despite BIS certification for ‘Morpholine'
# Hot Stocks: 3 concerns behind $13 bn rout in HDFC Bank; brokerages downgrade LTIMindtree
# ICICI Prudential Hit 10% Lower Circuit After Q3 Results
# Ultratech Cement Q3 result preview: Profit may surge 70% YoY on higher revenue, lower costs
# LTIMindtree shares tumble 10% on weak Q3 earnings, ratings downgrades. How to trade now?
# Buy PVR INOX, target price Rs 2240:  ICICI Securities
# Positive on Asian Paints from a one-year perspective: Abneesh Roy
# Asian Paints To Decide On Price Cuts After Assessing Geopolitical Risks, Says CEO
# Expect a deeper correction; not buying anything at this point of time: Dipan Mehta
# Indian Rupee Opens Weaker Against The U.S. Dollar
# Sensex tumbles 800 points. Top 5 factors behind the stock market crash
# Telecom Q3 Results Preview: Revenue May Rise, Margin Expansion Capped By 5G Spends
# Bullish on HDFC Bank? It’s time to buy it now: Anand Tandon
# India takes investment spotlight while risks weigh in China: Suntory CEO Takeshi Niinami
# ayodhya-ram-mandir-ram-janmabhumi-inauguration-live-updates
# China's Mutual Funds Implode At Fastest Pace In Five Years As Stocks Sink
# India: Marketer’s dream or Piketty’s nightmare?
# Ramkrishna Forgings is riding the CV upswing, but stock at an elevated level
# China Swap Market Goes Into Overdrive As Traders Seek FX Bypass
# Nifty bull run to last till April, but be very cautious from mid-May to July: Astro cycle expert
# Konstelec Engineers SME IPO: Check price band, GMP, financials, risks and listing date
# Morning or evening: Which is the better time to go on a walk for best fitness results?
# Dixon Tech may trade lower after inspection by DRI
# Agri Picks Report January 19, 2024: Geojit
# Bloodbath among risk-on assets – Disappointing HDFC earnings, or something more systemic?
# Dollar Dominance Is Triggering Intervention Fears Across Markets
# Q3 results today: RIL, HUL, Paytm, UltraTech among 46 companies to announce earnings
# Stock Market Live: Nifty, Sensex Higher In Pre-Open; RIL, SBI, Lupin, HUL In Focus
# RIL Q3 results today: What to expect from the conglomerate; how to trade the stock?
# Japan's space programs and moon missions
# Rising Interest Rates Threaten India’s Credit Growth And Pressure Margins
# Budget Snapshot: Do tax resets make Indians change investments?
# Gold set for weekly drop on tempered rate-cut view
# Japan counts down to precision 'moon sniper' landing mission
# Oil prices drift lower on China demand worries
# D-Street poised to snap 3-day losing run, IndusInd Bank, Polycab’s Q3 show and more | Market Minutes
# Ram Mandir inauguration updates Live: Odisha, Rajasthan govt declare half-day holidays on Jan 22
# Dollar headed for second weekly gain on tempered rates outlook
# Asian shares bounce on global tech rally, yen loser of the week
# Pakistani woman faces backlash for post praising groom who took Alto instead of luxury car to wedding
# Cash Market | PNB shows a robust underlying bullish trend
# US strikes Houthi anti-ship missiles, shipping disruptions grow
# This Segment Within Defence Stocks Is A Preferred Bet For Complete Circle's Gurmeet Chadha
# TSMC Outlook Drives $165 Billion Chip Rally In 2024 Rebound Bet
# Bank CEOs, huddled in Davos, said to worry on competition, economy
# Bangladesh solar power surge set to unlock thousands of green jobs
# Sensex Today | Stock Market LIVE Updates: GIFT Nifty signals a positive start; Asian shares trade higher
# YouTube And Spotify Won’t Launch Apple Vision Pro Apps, Joining Netflix
# Red Sea Unrest Is Bad News For The World’s Fragile Food Supply
# Bitcoin Retreats To One-Month Low As ETF-Led Enthusiasm Wanes
# Huthis say US ship hit in Gulf of Aden attack
# Global Passive Funds Put Added Strain On China’s Stock Rout
# Japan inflation slows in December as energy bills drop
# MC Policy Next | India may aim for a fiscal deficit of 5.3% for FY25: India Ratings' Pant
# budget-2024 expectations live union budget fm sitharaman modi budget interim budget
# Stock Radar I Eye on FMCG space! United Breweries is in a steady long-term uptrend: Ajit Mishra
# Is the RBI targeting banking executives?
# Agri talks a no-go for India at WTO meet without public stockholding solution
# Stock Market Today: Top 10 things to know before the market opens
# Bosch aims to cut 1,200 jobs in software division by end 2026
# Asian Equities Rise As Tech Rally Bolsters Mood: Markets Wrap
# Google to invest $1 billion in UK data centre
# Meta ramps up AI efforts by building chip arsenal, consolidating teams
# MC Exclusive | India at the forefront of energy transition: power minister RK Singh
# ESMA likely to seek board help to resolve stalemate with RBI
# SBI taps ARCs for sale of Hindusthan National Glass loan
# FPI ownership of Indian g-secs surges to a record
# Central Bank, 10 others file bids for Future Enterprises assets
# IndusInd's Q3 Net Up 17% on Strong Retail Loan Demand
# Sony calls board meeting today for Zee merger call
# Hot Stocks: Amber Enterprises, Lupin, Rail Vikas Nigam may fetch double-digit returns
# Pre-market action: Here's the trade setup for today's session
# Stocks in news: RIL, Paytm, HUL, IndusInd Bank, HDFC Bank
# Ahead of IPO, EPACK Durable mobilises Rs 192 crore from anchor investors
# Rashi Peripherals IPO | Madhu Kela's wife, Volrado Venture invest Rs 150 cr before RHP
# IndusInd Bank to open 4 more branches in Ayodhya
# Oracle Financial Services soars 27%, analysts still optimistic
# Moneycontrol Daily: Your Essential 7
# SBI raises Rs 5,000 crore through AT-1 bonds
# FPI selloff in HDFC could boost weight in MSCI index
# FPIs breaching exposure levels to reveal ODI holder details
# Reliance Industries, HUL, UltraTech Cement Q3 Results Today — Earnings Estimates
# Stock Market Today: All You Need To Know Going Into Trade On Jan. 19
# Stocks To Watch: IndusInd Bank, SBI, REC, JSW Infrastructure, Lupin, Bandhan Bank, Wipro
# 71% Of Indian Retailers Plan To Adopt Generative AI In Next 12 Months: EY Survey
# Vulnerability to climate change making food inflation structural: RBI economists
# Illegal constructions demolished from govt land worth Rs 87 crore in Greater Noida
# Israel-Hamas war tensions inflame the Middle East as fighting persists in Gaza
# Netanyahu says he has told US that he opposes Palestinian state in any postwar scenario
# BSF carries out search op after reports of suspicious tunnel in J-K's Samba
# Lufthansa pulling flight capacity from other countries to meet booming India demand
# Death of bus passengers by electrocution: After NHRC recommendations, Rajasthan to pay Rs 30L relief
# EAM Jaishankar, Maldivian Foreign Minister Zameer hold talks in Kampala
# BlackRock’s Bitcoin ETF Is First To Cross $1 Billion Threshold In Inflows
# IndiGo Evaluating Options To File Appeal Against BCAS Order
# Davos Diaries 2024: India's Emergence And The Quest For Global Trust
# Mahindra expects to sustain growth momentum in SCV segment next fiscal
# Tata Steel to shut down blast furnaces in UK, 3,000 jobs at risk: Reports
# Jawa Yezdi Motorcycles eyes ASEAN market for Jawa exports
# 'Khichdi scam' case: Shiv Sena (UBT) functionary sent to ED custody till Jan  22
# MEHAIR Places Conditional Order For Up To 20 ZA600 Hydrogen-Electric Engines With ZeroAvia
# India Central Bank Not Discussing Rate Cuts Yet, Shaktikanta Das Says
# Alaska Air Passengers Sue Airline Over 737 Max 9 Door Blowout
# Don't park planes in remote bays when there are long flight delays: MoCA tells airlines
# Sense Of Urgency Required To Tackle Intertwined Crises Of Climate, Poverty, Fragility: World Bank Chief
# Exclusive-Reddit seeks to launch IPO in March: Sources
# TRP Rigging: No Objection To Police Plea To Withdraw Case, Complainant Tells Court
# India, France to jointly fund science research projects
# FinAGG Technologies Secures $11 mn Funding Led By Blue Orchard, Tata Capital
# India must sustain growth momentum, secure at least 7% growth in FY25 - RBI bulletin
# Trade setup for Friday: 15 things to know before opening bell
# Passenger assaulting pilot unacceptable' says IndiGo CEO Pieter Elbers
# EPACK Durable Mobilises Rs 192 Crore From Anchor Investors Ahead Of IPO
# Jindal Stainless Reports 35% Rise In Q3 Net Profit; Sales Grow 9% To 5.12 LT
# Davos 2024: India Offers Opportunity For Manufacturing, Says Tamil Nadu Minister TRB Rajaa
# Global Leaders Meet DPIIT Secretary, Express Commitment To India Growth Story
# Boosting Iron Ore Production To Meet Domestic Demand; No Plans For China Exports: NMDC
# US bonds keep bearish tone after strong jobs data
# Four persons crushed to death by express train in Jharkhand
# 'Historic moment': Hindu outfits in UK welcome Ram temple consecration ceremony
# Antunes opens new unit in city to serve quick service restaurants
# Integrow to invest ₹100 crore in Paranjpe Scheme’s realty project
# Airstrikes On Yemen Bring New Level Of Chaos To Shipping In The Southern Red Sea
# Torrent Power Raises Rs 750 Crore Via Non-Convertible Debentures
# U.S. Jobless Claims Plunge To 187,000, Lowest Since September 2022
# Davos 2024: Clients charged up about Gen AI, says Infosys CEO Salil Parekh
# ‘Mobile services will cost more after polls’
# Ahead of Market: 10 things that will decide D-Street action on Friday
# SBI raises ₹5,000 crore through bond issue
# Gift Nifty, HDFC ADR shares show signs of positivity, trade higher
# India Plans To Push WTO To Ease Subsidy Rules On Grain Purchase
# Time ripe for aircraft assembly line in India: Scindia
# Davos 2024: PM Modi’s successful foreign policy will make India major semiconductor destination in 5 years, says Ashwini Vaishnaw
# Davos 2024: India To Be Key Player In Green Ecosystem, Says INOX Group's Siddharth Jain
# Sexual pleasure is 'a gift from God', lust 'devastates relationships' says Pope Francis
# Birkenstock falls 14% as investors focus on profit warning in first post-IPO results
# Ayodhya Ram Mandir: Bus travel spikes ahead of inauguration, more services in offing
# Davos 2024: HCLTech CEO Vijayakumar Expects Discretionary Spending To Pick Up
# Ahead of IPO, Epack Durables raises Rs 192 crore from marquee investors in anchor round
# Epack Durable IPO | Institutional investors pick Rs 192 crore shares via anchor book
# Coal India likely to mine critical minerals
# Passengers grab phone snatcher through train window, drag him for 1 km. Video
# Puravankara posts 89% growth in pre-sales in 9 months
# Orry's viral clip from Koffee with Karan has the internet 'uncomfortable and intrigued'. Watch
# FinAGG Technologies raises $11 million in Series A funding round
# Mahua Moitra says she's hospitalised, urges HC for direction to authorities to not evict her from govt bungalow
# Illicit crypto addresses received at least $24.2 billion in 2023: Report
# South Indian Bank Q3 Results: Net profit soars 197% YoY to Rs 305.36 crore
# NSE Remains World's Largest Derivatives Exchange For Fifth Straight Year
# Economy to log stronger-than expected growth in FY24: RBI officials
# Spot bitcoin ETFs draw nearly $2 billion in first three days of trading
# Ashok Leyland bags orders for 1,225 Viking buses from Karnataka STUs
# MC Exclusive: Govt mulls compulsory fake review prevention system for e-commerce platforms
# US bank regulator: New liquidity rules needed to handle bank runs
# Jeh Aerospace Raises $2.75 Million From General Catalyst, Others
# DefSat Conference To Bring Space Strategists Together From Feb 7-9
# Bulk deals: Citibank sells further stake in Grasim, foreign investor sells IEX shares
# Davos 2024: Shaktikanta Das Expects 7% Real GDP Growth In FY25, Inflation To Moderate
# REC Designated As Implementation Agency For Rooftop Solar Programme
# Birkenstock Q4 Results: Company beats revenue expectations on strong demand
# Consumer affairs get daily data from 550 centres on 22 food commodities: Rohit Kumar Singh
# Iran-Pakistan conflict: Regional equilibrium teeters, global powers on edge
# NSE world's largest derivatives exchange for fifth year in a row; third in equity
# S&P 500, Nasdaq open higher on chips, megacaps boost
# After Pakistan's counter-strikes on Iran, China offers to play a constructive role  to ease tensions
# Paytm Q3 preview: Strong revenue growth, narrower net loss seen on better operating performance
# DBS Bank Collaborates With StartupTN To Provide Support To Over 1,000 Early-Stage Enterprises
# Startup Groyyo Secures Rs 40 Crore Funding From Lighthouse Canton, Trifecta Capital
# FSSAI Directs Airline Caterers To Comply With Food Safety Rules
# Govt launches fresh incentive scheme for green hydrogen, green ammonia production based on demand aggregation
# Tata Communications posts fastest quarterly revenue growth in 9 years
# US applications for jobless benefits fall to lowest level since September 2022
# Alpha Wave-backed Groyyo secures $5.4 million in venture debt
# RBI calls upon internal ombudsmen to give inputs for enhancing processes
# On camera, TTE slaps passenger repeatedly on Barauni-Lucknow Express. Railway Minister reacts
# Matter of concern: India on situation in Red Sea
# Indian economy poised to sustain growth momentum: RBI report
# Metro Brands Q3 net profit declines 12.6 pc to Rs 98.78 cr
# Higher US yields, hawkish cenbank comments push India bond yields up
# India Estimated To Have Harvested 355.35 mn Tonnes Horticulture Crops In 2022-23: Agri Ministry Data
# Govt May Look For Providing Incentives Or Supporting Initiatives To Retrofit Old Vehicles Into EVs: Report
# Gold climbs as weaker dollar, safe-haven demand lend support
# FPIs Stay Net Sellers For The Second Straight Day
# ET Market Watch: Sensex and Nifty close lower, HDFC Bank & LTIMindtree slip
# Market Trading Guide: Bank of Maharashtra, Castrol India among 5 stock recommendations for Friday
# Puravankara Shares Surge After Company Unveils 2nd Plotted Development Project Near Chennai
# Sebi issues demand notices to DHFL's former promoters in disclosure rule violation case
# Top Seven Business And Stock Market News Of The Day You Can't Miss — Jan. 18
# RBI Governors says topic of rate cut not on table at this time, focus to bring inflation to 4%
# Metro Brands Q3 net profit declines 12.6% to Rs 98.78 crore
# Six school students on picnic die as boat overturns in lake near Vadodara; several others missing
# IESA demands 10-year tax holiday on standalone battery energy storage using renewables
# Gem, Jewellery Exports Slip 8.14% To Rs 18,281 Crore In December: GJEPC
# PhonePe Sells 90 Lakh Digital Insurance Policies, 40 Lakh In Just One Year
# Market Rally Has Margin Trading Book Hitting A Record Rs 54,537 Crore In Jan
# Davos 2024: Japanese Monetary Authority to adopt India's digital payment models says Ashwini Vaishnaw
# Davos 2024: Apollo Tyres Expanded Return On Capital Employed Using AI, Says Vice Chairman
# HDFC Bank share crash and the perils of equity funds that hug their benchmarks
# Brave Souls Foundation's Fight for Acid Attack Survivors | Badlaav Humse Hai Season 2
# Aadhaar will not be considered as valid proof of date of birth: EPFO
# IndiGo vows to return to earlier on-time performance standards
# OpenAI Coup Less Stressful Than Superintelligent AI, Sam Altman Says
# Oil Squeeze Of 2023 Turns To Surplus In Warning For Market Bulls
# 8 financial services stocks hit 52-week highs; rallied up to 55% in a month
# Mysuru-Based Rangsons Aerospace Inks 5-Year Contract With Boeing
# KRN Heat Exchanger Files Draft Papers To Raise Funds Via IPO
# Lupin Gets USFDA Nod to Market Generic Hyperuricemia Treatment Drug
# ICRA Projects GDP Growth To Moderate To Below 6% In Q3
# Maersk Opens New Cold-Chain Facility In Gujarat
# IHCL Opens Hotel In Jaisalmer
# Reddit seeks to launch IPO in March
# RBI hasn't mandated number on CD ratio: Governor
# Rupee rises 2 paise to 83.12 against U.S. dollar
# Energy Efficiency Services inks 5 initial pacts to boost energy efficiency, renewables
# Davos 2024: RMZ Corp's Manoj Menda Sees India As Most Promising Real Estate Market In 2024
# Moneycontrol Policy Next LIVE | Navigating India's $10 trillion economy
# True Detective Night Country review: Jodie Foster & Co deliver one of the franchise’s best seasons
# Government to sell additional 1% stake in NHPC as OFS gets overwhelming response
# Ram Mandir Ayodhya: Here’s everything about the ‘Time Capsule’ readied to be placed 2,000 feet under temple
# India needs 2,840 new aircraft, 41,000 pilots in next 20 years: Airbus forecast
# RBI imposes monetary penalty on three cooperative banks
# Bengaluru blushes as pink blossoms shroud city in glory. How they came to India
# Wings India 2024: Asia's premier aviation event marks India's industry growth, global recognition
# Woman arrested for staying at Delhi 5-star hotel for 15 days without paying
# Ashok Leyland Secures Supply Order For 1,225 Buses For Karnataka State Transport Undertakings
# NHPC OFS: Institutional Buyers Put In Bids Worth Rs 6,000 Crore
# Technical Breakout Stocks: How to trade OFSS, PCBL and Sobha on Friday
# House Of Abhinandan Lodha To Invest Rs 1,200 Crore In Ayodhya
# Commerce Ministry To Launch Portal To Provide Info For Aspiring Exporters
# Airbus Forms JV With Air India To Launch Pilot Training Centre in Gurugram
# Stock market update: Fertilisers stocks  down  as market  falls
# JK Tyre, Saregama among 6 smallcap stock picks by Emkay
# Jet Airways Case: Top Court Asks Jalan-Kalrock Consortium To Deposit Rs 150 Crore By Month-End
# Pakistan’s Army Strikes Back At Iran As Both Sides Urge Calm
# Nifty Bank falls for 3rd day, closes below 46,000; next support seen at 45,500
# Pakistan conducts 'precision military strikes' against 'terrorist hideouts' in Iran's Siestan-Balochistan province, 9 killed
# Gainers & Losers: LTIMindtree, Oracle Financial among top 5 stocks in spotlight
# More banks rush to Ayodhya eyeing business opportunities
# GMR Group, IndiGo Airlines Tie Up For Digital Transformation In Indian Aviation
# Meta Says Its AI Tools Boost Ad Campaigns’ Returns By 32%
# Oil Markets Look ‘Reasonably Well Supplied’ In 2024, IEA Says
# IEX, ICICI Lombard General Insurance among 5 stocks with top-long unwinding
# A decade in turmoil: Here is the timeline of tensions in Iran-Pakistan conflict
# Tea Board Mandates Generation Of Tea Waste Not Exceeding 0.2% Of Production
# Ayodhya Ram Mandir | Whose land is it anyway — events and legal cases from 1608 to 1992
# Markets Will See A Comeback If Nifty Sustains Above 21,450, Say Analysts
# Puravankara to develop 3 million sq ft of residential space in Chennai, announces launch of largest plotted development
# Interest Rates To Keep Falling But Last Mile 'Very Very Tricky': IMF Chief
# Share market update: Most active stocks in today's market in terms of volume
# Welspun Corp's Associate Arm EPIC Bags Rs 3,000 Crore Orders In Saudi Arabia
# Akasa Air, IndiGo, Air India Place Orders For 1,120 Planes In Less Than One Year
# Aether Industries Partners With Novoloop For Sustainable Plastic Management
# India among most vibrant fintech hubs: WEF study
# France ramps up weapons production for Ukraine and says Russia is scrutinizing the West's mettle
# Davos 2024: India to be fastest growing G20 economy, will drive global growth, says OECD chief
# Weak earnings, fading US rate cut hopes drag Indian shares
# Sterling and Wilson Renewable Energy loss narrows in Dec quarter
# Oil prices rise on strong IEA and OPEC demand estimates
# Stock market update: Stocks that hit 52-week highs on NSE in today's trade
# LTIMindtree portfolio of revenues rebalancing, holds better promise for multi-year growth path: Sudhir Chaturvedi
# SBI Raises Rs 5,000 Crore Through AT-1 Bonds At Coupon Of 8.34%
# RIL Q3 results preview: Here's what to expect
# Polycab Q3 Results: Profit Rises In Line With Estimates
# Airbus says to double procurement from India to $1.5 billion
# ...
# Paytm Q3 preview: Strong revenue growth, narrower net loss seen on better operating performance
# DBS Bank Collaborates With StartupTN To Provide Support To Over 1,000 Early-Stage Enterprises
# Startup Groyyo Secures Rs 40 Crore Funding From Lighthouse Canton, Trifecta Capital
# FSSAI Directs Airline Caterers To Comply With Food Safety Rules
# Govt launches fresh incentive scheme for green hydrogen, green ammonia production based on demand aggregation
# US applications for jobless benefits fall to lowest level since September 2022
# Alpha Wave-backed Groyyo secures $5.4 million in venture debt
# RBI calls upon internal ombudsmen to give inputs for enhancing processes
# On camera, TTE slaps passenger repeatedly on Barauni-Lucknow Express. Railway Minister reacts
# Matter of concern: India on situation in Red Sea
# Indian economy poised to sustain growth momentum: RBI report
# Metro Brands Q3 net profit declines 12.6 pc to Rs 98.78 cr
# Higher US yields, hawkish cenbank comments push India bond yields up
# India Estimated To Have Harvested 355.35 mn Tonnes Horticulture Crops In 2022-23: Agri Ministry Data
# Govt May Look For Providing Incentives Or Supporting Initiatives To Retrofit Old Vehicles Into EVs: Report
# Gold climbs as weaker dollar, safe-haven demand lend support
# FPIs Stay Net Sellers For The Second Straight Day
# ET Market Watch: Sensex and Nifty close lower, HDFC Bank & LTIMindtree slip
# Market Trading Guide: Bank of Maharashtra, Castrol India among 5 stock recommendations for Friday
# Puravankara Shares Surge After Company Unveils 2nd Plotted Development Project Near Chennai
# Sebi issues demand notices to DHFL's former promoters in disclosure rule violation case
# Top Seven Business And Stock Market News Of The Day You Can't Miss — Jan. 18
# RBI Governors says topic of rate cut not on table at this time, focus to bring inflation to 4%
# Metro Brands Q3 net profit declines 12.6% to Rs 98.78 crore
# Six school students on picnic die as boat overturns in lake near Vadodara; several others missing
# IESA demands 10-year tax holiday on standalone battery energy storage using renewables
# Gem, Jewellery Exports Slip 8.14% To Rs 18,281 Crore In December: GJEPC
# PhonePe Sells 90 Lakh Digital Insurance Policies, 40 Lakh In Just One Year
# Market Rally Has Margin Trading Book Hitting A Record Rs 54,537 Crore In Jan
# Davos 2024: Japanese Monetary Authority to adopt India's digital payment models says Ashwini Vaishnaw
# Davos 2024: Apollo Tyres Expanded Return On Capital Employed Using AI, Says Vice Chairman
# HDFC Bank share crash and the perils of equity funds that hug their benchmarks
# Brave Souls Foundation's Fight for Acid Attack Survivors | Badlaav Humse Hai Season 2
# Aadhaar will not be considered as valid proof of date of birth: EPFO
# IndiGo vows to return to earlier on-time performance standards
# OpenAI Coup Less Stressful Than Superintelligent AI, Sam Altman Says
# Oil Squeeze Of 2023 Turns To Surplus In Warning For Market Bulls
# 8 financial services stocks hit 52-week highs; rallied up to 55% in a month
# Mysuru-Based Rangsons Aerospace Inks 5-Year Contract With Boeing
# KRN Heat Exchanger Files Draft Papers To Raise Funds Via IPO
# Lupin Gets USFDA Nod to Market Generic Hyperuricemia Treatment Drug
# ICRA Projects GDP Growth To Moderate To Below 6% In Q3
# Maersk Opens New Cold-Chain Facility In Gujarat
# IHCL Opens Hotel In Jaisalmer
# Reddit seeks to launch IPO in March
# RBI hasn't mandated number on CD ratio: Governor
# Rupee rises 2 paise to 83.12 against U.S. dollar
# Energy Efficiency Services inks 5 initial pacts to boost energy efficiency, renewables
# Davos 2024: RMZ Corp's Manoj Menda Sees India As Most Promising Real Estate Market In 2024
# Moneycontrol Policy Next LIVE | Navigating India's $10 trillion economy
# True Detective Night Country review: Jodie Foster & Co deliver one of the franchise’s best seasons
# Government to sell additional 1% stake in NHPC as OFS gets overwhelming response
# Ram Mandir Ayodhya: Here’s everything about the ‘Time Capsule’ readied to be placed 2,000 feet under temple
# India needs 2,840 new aircraft, 41,000 pilots in next 20 years: Airbus forecast
# RBI imposes monetary penalty on three cooperative banks
# Bengaluru blushes as pink blossoms shroud city in glory. How they came to India
# Wings India 2024: Asia's premier aviation event marks India's industry growth, global recognition
# Woman arrested for staying at Delhi 5-star hotel for 15 days without paying
# Ashok Leyland Secures Supply Order For 1,225 Buses For Karnataka State Transport Undertakings
# NHPC OFS: Institutional Buyers Put In Bids Worth Rs 6,000 Crore
# Technical Breakout Stocks: How to trade OFSS, PCBL and Sobha on Friday
# House Of Abhinandan Lodha To Invest Rs 1,200 Crore In Ayodhya
# Commerce Ministry To Launch Portal To Provide Info For Aspiring Exporters
# Airbus Forms JV With Air India To Launch Pilot Training Centre in Gurugram
# Stock market update: Nifty Pharma index  advances  1.03%
# JK Tyre, Saregama among 6 smallcap stock picks by Emkay
# Jet Airways Case: Top Court Asks Jalan-Kalrock Consortium To Deposit Rs 150 Crore By Month-End
# Pakistan’s Army Strikes Back At Iran As Both Sides Urge Calm
# Nifty Bank falls for 3rd day, closes below 46,000; next support seen at 45,500
# Pakistan conducts 'precision military strikes' against 'terrorist hideouts' in Iran's Siestan-Balochistan province, 9 killed
# Gainers & Losers: LTIMindtree, Oracle Financial among top 5 stocks in spotlight
# More banks rush to Ayodhya eyeing business opportunities
# GMR Group, IndiGo Airlines Tie Up For Digital Transformation In Indian Aviation
# Meta Says Its AI Tools Boost Ad Campaigns’ Returns By 32%
# Oil Markets Look ‘Reasonably Well Supplied’ In 2024, IEA Says
# IEX, ICICI Lombard General Insurance among 5 stocks with top-long unwinding
# A decade in turmoil: Here is the timeline of tensions in Iran-Pakistan conflict
# Tea Board Mandates Generation Of Tea Waste Not Exceeding 0.2% Of Production
# Ayodhya Ram Mandir | Whose land is it anyway — events and legal cases from 1608 to 1992
# Markets Will See A Comeback If Nifty Sustains Above 21,450, Say Analysts
# Puravankara to develop 3 million sq ft of residential space in Chennai, announces launch of largest plotted development
# Interest Rates To Keep Falling But Last Mile 'Very Very Tricky': IMF Chief
# Welspun Corp's Associate Arm EPIC Bags Rs 3,000 Crore Orders In Saudi Arabia
# Akasa Air, IndiGo, Air India Place Orders For 1,120 Planes In Less Than One Year
# Aether Industries Partners With Novoloop For Sustainable Plastic Management
# India among most vibrant fintech hubs: WEF study
# France ramps up weapons production for Ukraine and says Russia is scrutinizing the West's mettle
# Davos 2024: India to be fastest growing G20 economy, will drive global growth, says OECD chief
# Weak earnings, fading US rate cut hopes drag Indian shares
# Sterling and Wilson Renewable Energy loss narrows in Dec quarter
# Oil prices rise on strong IEA and OPEC demand estimates
# Stock market update: Stocks that hit 52-week highs on NSE in today's trade
# LTIMindtree portfolio of revenues rebalancing, holds better promise for multi-year growth path: Sudhir Chaturvedi
# SBI Raises Rs 5,000 Crore Through AT-1 Bonds At Coupon Of 8.34%
# RIL Q3 results preview: Here's what to expect
# Polycab Q3 Results: Profit Rises In Line With Estimates
# Airbus says to double procurement from India to $1.5 billion
# With GPT Store, OpenAI is going after the attention economy
# These 5 smallcap MFs gave over 55% returns in a year
# Gainers and Losers: 10 stocks that moved the most on January 18
# KRN Heat Exchanger and Refrigeration files papers for IPO
# Haldiram's seeks to buy Indian chips maker Prataap Snacks
# Live: How can technology amplify humanity? Sam Altman at WEF | Davos 2024
# 2 stocks to buy in a melting market: CA Rudramurthy BV
# MC Interview | Infra co boards reluctant to invest, revamp of PPP model may help assuage concerns: Vinayak Chatterjee
# Market Live: Nifty ends below 21,500, Sensex slips 314 pts; Pharma shines, Banks slip| Bajar Gupshup
# Sensex falls for third day, ends 314 points lower dragged by financials
# Going forward, Asian Paints may need to revise margin guidance in Q4 and Q1:  Amit Syngle
# Ajmera Realty, Keystone Realtors Partner To Redevelop Housing Project Worth Rs 760 crore
# Experts Hail India's Digital Public Infra For Reducing Inequality
# Accenture, SandboxAQ Tie Up Over AI-Driven Threat, Quantum-Based Decryption Attack Protection
# Dynamatic Technologies Shares Hit Fresh Record On Inking Contract With Dassault Aviation
# Apollo Tyres, RVNL among 5 midcaps that hit fresh 52-week highs on Thursday
# Ram Lalla Pran Pratishtha: Centre declares half-day holiday for central government offices on January 22
# Budget 2024: Elevated public debt levels are here to stay
# Polycab India Q3 Results: Consolidated PAT rises 15% YoY to Rs 413 crore; revenue up 17%
# Bounce partners with SUN Mobility to deploy 30,000 EV scooters by February
# Will take darshan of Lord Ram in Ayodhya after construction of temple is over: Digvijaya Singh
# Nearly 100 Deals Involving 2,707 Acres Closed In 2023: Anarock
# Flight delayed or cancelled without notice? here’s what you can do
# Moneycontrol Pro Panorama | Are the odds against equities rising?
# Transparent system, people's participation led to poverty decline: PM Modi
# Mahindra Holidays & Resorts India to invest Rs 800 crore to set up 3 new resorts in Tamil Nadu
# Ayodhya Ram Mandir FAQs: From cost of temple to guest list, all you need to know
# Sandeep Tandon on taking the right call to sell banks and how to navigate the difficult phase of bull market
# D-Street Wishlist: 8 likely changes in Interim Budget that investors must watch out for
# F&O stocks: HDFC Bank, Asian Paints among 5 stocks with short buildup
# MS Dhoni Defamation Case: What Is It About?
# Coal India Units Get Cabinet Nod For Equity Investment In Thermal Power Plants
# Medical devices firm SIGH plans to set up manufacturing facility in Hyderabad with ₹231.5 crore
# LTIMindtree shares  down  10.39% as Sensex  falls
# Bitcoin ETF approval: How has the crypto market outlook changed
# Hudco on the verge of breakout, technical analyst recommends 'buy' in Rs 136-138 zone
# RK Vishnoi on NHPC’s roadshow, OFS plans and future plans
# Union Budget 2024: Ensure low cost capital to buyers and sellers and lower taxation on real estate
# Indian Banking System Is Robust: RBI Governor Shaktikanta Das To Moneycontrol | #Exclusive | Davos
# Davos 2024: Atal Setu Sea Link will increase connectivity in Mumbai, says HCC's Ajit Gulabchand
# Hockey Olympics qualifier semifinal: India Women look for deliverance as they take on Germany
# 71% of wealthy Indians seek luxury real estate, Goa top hotspot for vacation homes: ISIR Survey
# Dolly Khanna trims stake in multibagger Chennai Petroleum, cuts in 2 smallcaps
# Airbus signs pact with Tata Advanced Systems, Mahindra Aerospace Structures for aircraft components
# IPO rush isn't a bubble, but out of 10 issuances, we may pick 1 or 2: Bandhan AMC’s Manish Gunwani
# Qualitek Labs IPO: Check subscription on Day 1, GMP and other details
# Ashish Kacholia trims stake in multibagger Balu Forge, hikes in this smallcap
# Indian Railways To Learn Swiss Railway's Best Practices, Says Vaishnaw
# Air Passenger Traffic In India Likely To Reach 300 Million By 2030: Jyotiraditya Scindia
# Zee Ent. shares  rise  3.35% as Nifty  drops
# Zee shares rally 7% on report Punit Goenka offers to step down to seal Sony merger deal
# LTIMindtree Won’t Be As Profitable As Expected In Fiscal 2024, CEO Says
# Where to invest within the pharma theme? Industry expert Kewal Handa answers
# Crypto Price Today: Bitcoin trades near $42,800; Polygon, Toncoin shed up to 4.5%
# Arvind Kejriwal to visit Goa for three-day visit amid ED summons
# Unicorns selfie: 'Startups club' discussion with Piyush Goyal continued till 11pm, says Paytm CEO
# Cabinet approves creation of three posts for 16th Finance Commission
# Priyanka Chopra, Nick Jonas celebrate daughter Malti's 2nd birthday with special puja. Madhu Chopra joins
# Samsung to bring Galaxy AI features to S23 series, Tab S9 and Z foldables
# RIL Q3 result preview: PAT, revenue likely to see modest growth YoY on weak O2C show
# Boeing Wins Order For 150 Max Jets From Akasa Air
# HDFC Bank: Unbridled Expectations Or Communication Gap?
# Osiajee Consolidated December 2023 Net Sales at Rs 0.43 crore, down 38.85% Y-o-Y
# Sun Pharma's Move To Fully Acquire Taro Is A Good Proposition, Say Analysts
# Want to create wealth? 5 themes which investors should track in 2024: Varun Saboo
# Akasa Air places order for 150 Boeing 737 Max planes
# Covid-19: India Logs 305 New Cases
# Coforge, Mphasis among 5 stocks with short buildup
# Maharashtra Inked MoUs Worth Rs 3.53 Lakh Crore At WEF In Davos: CM Shinde
# Sensex, Nifty Trade Lower As HDFC Bank, LTIMindtree, Asian Paints Drag: Midday Market Update
# Are the bulls getting tired now?  How long will the rally across PSUs continue? Harsha Upadhayaya explains
# Delhi Weather News LIVE Updates: Fog disrupts visibility and rail traffic in North, northeast India
# Persistent Systems’ board to consider stock split; share volatile
# ICICI Pru Life shares tank 10% post muted Q3 earnings show
# GM Mustard: SC reserves order on pleas seeking moratorium on release of GMOs into environment
# Aarti Industries rallies 8% on Rs 6,000-cr chemical deal with multinational
# Vinati Organics Q3 PAT may dip 29.8% YoY to Rs. 88 cr: Prabhudas Lilladher
# 2024 - Year of opportunities!
# International Battery Company raises $35 million led by RTP Global
# Oracle Financial Services Software zooms 20% to record high on robust Q3 numbers
# Exploring the Benefits of a Small Personal Loan from Poonawalla Fincorp
# Beyond 3:30 pm! Why extending stock market timings should be explored
# HCL Tech To Collaborate With Cisco For Cloud-Native Solutions
# Taro announces merger with Sun Pharma in ₹2,892 crore deal
# Budget may disappoint stocks related to government capex: Jefferies
# Despite selling by Dalal Street big bulls, 4 smallcap stocks turned multibaggers in Q3
# Slight cannibalisation always happens but Tatas launching EVs in distinctly different segments: Shailesh Chandra
# Shares of Shree Cements  fall  as Nifty  drops
# Technical Stock Pick: ONGC hits 52-week high in January 2024, rallies over 20% in 3 months – should you buy, sell or hold?
# Spiritual Tourism is the new buzzword on D-St! Don’t ignore these 6 stocks for your long term portfolio
# ICICI Pru Life sees biggest crash in one year, stock down 10% after Q3 misses estimates
# Gold Rate Today: Yellow metal’s 2024 losses rise to Rs 1,650/10 grams. What should traders do?
# BHEL looks at opportunities in India’s rising energy demand
# Maxposure IPO allotment soon: Check status, GMP, listing date and other details
# ‘Amazon fired me’: Employee loses job of 7 years over TikTok video
# Airbus, Air India to jointly set up training centre in India; aim to train 5000 pilots in the next decade
# Weak Communication By Management May Have Caused HDFC Bank's Market Fall—Exclusive
# Premonition? Mutual funds sold 2.5 crore shares of HDFC Bank last month
# Over 32% companies globally declared layoffs in 2023, IT services lead the league: Report
# LTI Mindtree Q3 FY24 – quarter marred by seasonality
# Asian Paints shares fall 6% post Q3 earnings. Should you buy, sell or hold?
# Davos 2024: 65% of employees working from office 3-5 days a week, says TCS CEO K Krithivasan
# Bengaluru techie’s mid-air horror of being trapped in SpiceJet loo:  ‘Was thrown around during landing’
# Tata Unit Agratas In India Is In Talks For Green Loan Of Up To $500 Million
# Asian Paints Q3: Brokerages positive on rural recovery, competition a worry. Buy, sell or hold?
# Could money move out of HDFC Bank to Bajaj Finance or is it time for sector rotation? Hemang Jani asnwers
# HDFC Bank shares tank 12% in 2 days in Rs 1.3 lakh-crore rout. No dip buyers left
# Buy Tarsons Products, target price Rs 670:  ICICI Securities
# HDFC Bank Extends Losses, Wipes Off Over Rs 43,000 Crore In Market Value

# %%
import requests
from bs4 import BeautifulSoup

# Replace the URL with the actual website URL


# Define your search query
search_query = 'HDFC Bank'

# Perform a GET request to the website
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the search form element by its HTML attribute (e.g., name, id, class)
    search_form = soup.find('form', {'id': 'search-form'})  # Replace with the actual attribute

    # Extract the action URL and any other form parameters
    form_action = search_form.get('action')
    form_data = {
        'search': search_query,
        # Add any other form parameters as needed
    }

    # Perform a POST request with the search query
    search_results = requests.post(url + form_action, data=form_data)

    # Parse the search results using BeautifulSoup
    search_soup = BeautifulSoup(search_results.text, 'html.parser')

    # Extract and print relevant information from the search results
    headlines = search_soup.find_all('h2', {'class': 'headline-class'})

    if headlines:
        for index, headline in enumerate(headlines, start=1):
            print(f"{index}. {headline.text}")
    else:
        print("No headlines found.")

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 14>()
#      19 search_form = soup.find('form', {'id': 'search-form'})  # Replace with the actual attribute
#      21 # Extract the action URL and any other form parameters
# ---> 22 form_action = search_form.get('action')
#      23 form_data = {
#      24     'search': search_query,
#      25     # Add any other form parameters as needed
#      26 }
#      28 # Perform a POST request with the search query
#
# AttributeError: 'NoneType' object has no attribute 'get'
